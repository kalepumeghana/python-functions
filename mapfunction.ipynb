# %%
a=[24,12.5,56,9]
def cel(x):
    return x*(9/5)+32
n=list(map(cel,a))
print(n)
# Out:
# [75.2, 54.5, 132.8, 48.2]

# %%
st="hello"
n=list(map(ord,st))
print(n)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[21], line 2
#       1 st="hello"
# ----> 2 n=list(map(ord,st))
#       3 print(n)
#
# Cell In[12], line 3, in ord(x)
#       2 def ord(x):
# ----> 3     return ord(x)
#
# Cell In[12], line 3, in ord(x)
#       2 def ord(x):
# ----> 3     return ord(x)
#
# Cell In[12], line 3, in ord(x)
#       2 def ord(x):
# ----> 3     return ord(x)
#
# Cell In[12], line 3, in ord(x)
#       2 def ord(x):
# ----> 3     return ord(x)
#
# Cell In[12], line 3, in ord(x)
#       2 def ord(x):
# ----> 3     return ord(x)
#
# Cell In[12], line 3, in ord(x)
#       2 def ord(x):
# ----> 3     return ord(x)
#
# Cell In[12], line 3, in ord(x)
#       2 def ord(x):
# ----> 3     return ord(x)
#
# Cell In[12], line 3, in ord(x)
#       2 def ord(x):
# ----> 3     return ord(x)
#
# Cell In[12], line 3, in ord(x)
#       2 def ord(x):
# ...

# %%
a=[[1,2],[3,4],[5,6]]
def ele(x):
    x.append(5)
    return x
n=list(map(ele,a))
print(n)
# Out:
# [[1, 2, 5], [3, 4, 5], [5, 6, 5]]

# %%
a=[5,10,15,20,25,30]
def square(x):
    return x**2
n=list(map(square,a))
print(n)
# Out:
# [25, 100, 225, 400, 625, 900]

# %%
a=[5]
n=list(map(id,a))
print(n)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[36], line 2
#       1 a=[5]
# ----> 2 n=list(map(id,a))
#       3 print(n)
#
# Cell In[26], line 3, in id(x)
#       2 def id(x):
# ----> 3     return id(x)
#
# Cell In[26], line 3, in id(x)
#       2 def id(x):
# ----> 3     return id(x)
#
# Cell In[26], line 3, in id(x)
#       2 def id(x):
# ----> 3     return id(x)
#
# Cell In[26], line 3, in id(x)
#       2 def id(x):
# ----> 3     return id(x)
#
# Cell In[26], line 3, in id(x)
#       2 def id(x):
# ----> 3     return id(x)
#
# Cell In[26], line 3, in id(x)
#       2 def id(x):
# ----> 3     return id(x)
#
# Cell In[26], line 3, in id(x)
#       2 def id(x):
# ----> 3     return id(x)
#
# Cell In[26], line 3, in id(x)
#       2 def id(x):
# ----> 3     return id(x)
#
# Cell In[26], line 3, in id(x)
#       2 def id(x):
# ----> 3     return id(x)
#
# ...
