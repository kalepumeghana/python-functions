# %%
from pydoc_data import module_docs

n=lambda a:a**3
print(n(2))
# Out:
# 8

# %%
larger=lambda a,b:a if a>b else b
print(larger(10,20))
# Out:
# 20

# %%
a=lambda n:n%2==0
print(a(4))
# Out:
# True
