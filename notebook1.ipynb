# %%
l=[2.5,4.5,6.8]
k=list(map(lambda x:x*(9/5)+32),l)
print(k)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 l=[2.5,4.5,6.8]
# ----> 2 k=list(map(lambda x:x*(9/5)+32),l)
#       3 print(k)
#
# TypeError: map() must have at least two arguments.
